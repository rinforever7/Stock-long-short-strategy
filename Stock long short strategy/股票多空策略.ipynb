# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
import talib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.metrics import mean_squared_error
def individual(data1):
    #时间升序排列
    data=data1[::-1].reset_index(drop=True)
    trade_date = data['trade_date']
    # 计算EMA值
    ema = talib.EMA(data['close'].values, timeperiod=20)
    # 计算价格波动率
    stddev = talib.STDDEV(data['close'].values, timeperiod=20, nbdev=1)
    # 计算价格斜率
    slope = talib.LINEARREG_SLOPE(data['close'].values, timeperiod=5)
    # 计算RSI值
    rsi = talib.RSI(data['close'].values, timeperiod=14)
    # 计算威廉指标值
    wr = talib.WILLR(data['high'].values, data['low'].values, data['close'].values, timeperiod=7)
    # 计算真实成交量 (Accumulation/Distribution Line, AD)
    ad = talib.AD(data['high'], data['low'], data['close'], data['vol'])
    # 计算成交量变化率指标 (Accumulation/Distribution Oscillator, ADOSC)
    adosc = talib.ADOSC(data['high'], data['low'], data['close'], data['vol'], fastperiod=3, slowperiod=10)
    # 计算累积/派发线 (On Balance Volume, OBV)
    obv = talib.OBV(data['close'], data['vol'])
    # 计算平均趋向指数 (Average Directional Movement Index Rating, ADXR)
    adxr = talib.ADXR(data['high'], data['low'], data['close'], timeperiod=14)
    # 计算成交量震荡指标 (Chaikin Oscillator, CMO)
    cmo = talib.CMO(data['close'], timeperiod=14)
    # 将涨跌幅作为预测标签
    label = data['change']
    # 将计算结果组合成一个DataFrame
    result = pd.DataFrame({
        'trade_date': trade_date,
        'ema': ema,
        'stddev': stddev,
        'slope': slope,
        'rsi': rsi,
        'wr': wr,
        'AD': ad,
        'ADOSC': adosc,
        'OBV': obv,
        'ADXR': adxr,
        'CMO': cmo,
        'label':label
    })
    result.set_index('trade_date',inplace=True)
    # 预测的是第二天的涨跌幅
    result['label'] = result['label'].shift(1)
    result = result.iloc[1:]
    #后向填充缺失值
    result = result.fillna(method='bfill')

    # 选择所有特征列进行归一化
    float_columns = result.drop(['label'],axis=1).select_dtypes(include=['float64','int64'])
    scaler = MinMaxScaler(feature_range=(-1, 1))
    result[float_columns.columns] = scaler.fit_transform(float_columns)
    
    return result

# %%
#文件路径
current_directory = os.getcwd()
subdirectory_name = "data"
folder_path = os.path.join(current_directory, subdirectory_name)
file_names = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

all_data1 = pd.DataFrame()
for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    data1 = pd.read_csv(file_path)
    data1 = individual(data1)
    all_data1 = pd.concat([all_data1, data1])
all_data1=all_data1.drop('label',axis=1)
#计算市场某天的总体指标（均值实现）
market_avg = all_data1.groupby('trade_date').agg( 'mean')
market_avg
# Out:
#                  ema    stddev     slope       rsi        wr        AD  \
# trade_date
# 20230104    0.191683 -0.196397  0.201843  0.560198  0.083758  0.405375
# 20230105    0.191683 -0.196397  0.201843  0.560198  0.083758  0.431917
# 20230106    0.191683 -0.196397  0.201843  0.560198  0.083758  0.430841
# 20230109    0.191683 -0.196397  0.201843  0.560198  0.083758  0.440000
# 20230110    0.191683 -0.196397  0.173426  0.560198  0.083758  0.432012
# ...              ...       ...       ...       ...       ...       ...
# 20231225   -0.565984 -0.502526  0.036899 -0.281567  0.058926 -0.694837
# 20231226   -0.578140 -0.528678  0.049065 -0.342204 -0.100674 -0.708294
# 20231227   -0.585288 -0.549756  0.013373 -0.273284  0.062730 -0.683926
# 20231228   -0.583042 -0.580414  0.112208 -0.005059  0.509992 -0.631147
# 20231229   -0.577955 -0.602795  0.185262  0.032851  0.556593 -0.608343
#
#                ADOSC       OBV      ADXR       CMO
# trade_date
# 20230104    0.123062 -0.219746  0.253685  0.560198
# 20230105    0.123062 -0.159250  0.253685  0.560198
# 20230106    0.123062 -0.148162  0.253685  0.560198
# 20230109    0.123062 -0.109222  0.253685  0.560198
# 20230110    0.123062 -0.112641  0.253685  0.560198
# ...              ...       ...       ...       ...
# 20231225   -0.076102 -0.164853 -0.084177 -0.281567
# 20231226   -0.051449 -0.182510 -0.058449 -0.342204
# 20231227   -0.000979 -0.172334 -0.039121 -0.273284
# 20231228    0.143122 -0.110193 -0.043804 -0.005059
# 20231229    0.213513 -0.091099 -0.057979  0.032851
#
# [241 rows x 10 columns]

# %%
#定义函数，组合原指标和原指标与市场指标之差
def merge(result):
    result1 = result.drop(['label'],axis=1)
    #原指标与市场指标之差
    data = result1.sub(market_avg)
    #组合
    data = data.add_prefix('sub_')
    data1 = pd.concat([data, result], axis=1)
    #填充缺失值
    data1 = data1.fillna(method='ffill')
    data1 = data1.fillna(method='bfill')
    return data1

# %%
#数据集预览
merge(data1)
# Out:
#              sub_ema  sub_stddev  sub_slope   sub_rsi    sub_wr    sub_AD  \
# trade_date
# 20230104   -1.191683   -0.715547  -0.387504 -0.531851 -0.769708 -0.269929
# 20230105   -1.191683   -0.715547  -0.387504 -0.531851 -0.769708 -0.274075
# 20230106   -1.191683   -0.715547  -0.387504 -0.531851 -0.769708 -0.305722
# 20230109   -1.191683   -0.715547  -0.387504 -0.531851 -0.769708 -0.338643
# 20230110   -1.191683   -0.715547  -0.394493 -0.531851 -0.769708 -0.343749
# ...              ...         ...        ...       ...       ...       ...
# 20231225    0.960968   -0.379098  -0.353562 -0.305725 -0.925035 -0.080881
# 20231226    0.950272   -0.331152  -0.527711 -0.450757 -0.870256 -0.109944
# 20231227    0.937420   -0.285043  -0.553095 -0.503980 -0.703124 -0.119124
# 20231228    0.930841   -0.255065  -0.481980 -0.476119 -0.549400 -0.132969
# 20231229    0.920592   -0.239384  -0.301880 -0.536094 -0.638887 -0.177792
#
#             sub_ADOSC   sub_OBV  sub_ADXR   sub_CMO  ...    stddev     slope  \
# trade_date                                           ...
# 20230104    -0.096652 -0.670320 -0.659842 -0.531851  ... -0.911944 -0.185661
# 20230105    -0.096652 -0.740699 -0.659842 -0.531851  ... -0.911944 -0.185661
# 20230106    -0.096652 -0.765294 -0.659842 -0.531851  ... -0.911944 -0.185661
# 20230109    -0.096652 -0.815718 -0.659842 -0.531851  ... -0.911944 -0.185661
# 20230110    -0.096652 -0.804011 -0.659842 -0.531851  ... -0.911944 -0.221067
# ...               ...       ...       ...       ...  ...       ...       ...
# 20231225     0.204417  1.081340 -0.881705 -0.305725  ... -0.881623 -0.316663
# 20231226     0.093273  1.084030 -0.853356 -0.450757  ... -0.859830 -0.478646
# 20231227     0.029195  1.089623 -0.804022 -0.503980  ... -0.834799 -0.539721
# 20231228    -0.068349  1.047448 -0.786763 -0.476119  ... -0.835479 -0.369772
# 20231229    -0.146528  1.015209 -0.791812 -0.536094  ... -0.842180 -0.116619
#
#                  rsi        wr        AD     ADOSC       OBV      ADXR  \
# trade_date
# 20230104    0.028347 -0.685950  0.135445  0.026411 -0.890066 -0.406156
# 20230105    0.028347 -0.685950  0.157842  0.026411 -0.899949 -0.406156
# 20230106    0.028347 -0.685950  0.125119  0.026411 -0.913456 -0.406156
# 20230109    0.028347 -0.685950  0.101357  0.026411 -0.924940 -0.406156
# 20230110    0.028347 -0.685950  0.088263  0.026411 -0.916652 -0.406156
# ...              ...       ...       ...       ...       ...       ...
# 20231225   -0.587292 -0.866109 -0.775718  0.128315  0.916487 -0.965882
# 20231226   -0.792961 -0.970930 -0.818238  0.041824  0.901520 -0.911805
# 20231227   -0.777264 -0.640394 -0.803050  0.028215  0.917289 -0.843143
# 20231228   -0.481178 -0.039409 -0.764115  0.074773  0.937255 -0.830567
# 20231229   -0.503243 -0.082294 -0.786134  0.066985  0.924110 -0.849791
#
#                  CMO  label
# trade_date
# 20230104    0.028347   0.40
# 20230105    0.028347   0.38
# 20230106    0.028347  -0.05
# 20230109    0.028347  -0.19
# 20230110    0.028347  -0.15
# ...              ...    ...
# 20231225   -0.587292   0.22
# 20231226   -0.792961  -1.78
# 20231227   -0.777264  -1.16
# 20231228   -0.481178   0.06
# 20231229   -0.503243   1.22
#
# [241 rows x 21 columns]

# %%
def train(result,buy_parameter,sale_parameter):
    # 划分训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(result.drop('label',axis=1), result['label'] , test_size=0.2, random_state=42)
    #使用xgb进行回归
    model = xgb.XGBRegressor(objective ='reg:squarederror', random_state=42)

    # 在训练集上拟合模型
    model.fit(X_train, y_train)

    # 在训练集和测试集上进行预测
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    #设置购入条件，预测结果大于等于buy_parameter即可购入，实际为涨即算成功
    buy_indices = (y_test_pred >= buy_parameter)
    if not buy_indices.any():
        print('    没有购入条件')
    else:
        success_indices = (y_test > 0)
        success_rate = success_indices[buy_indices].sum() / buy_indices.sum()
        print('    多头成功率 ：'+'{:.5f}'.format(success_rate))
    
    #同理设置抛出条件
    sale_indices = (y_test_pred <= sale_parameter)
    if not sale_indices.any():
        print('    没有抛出条件')
    else:
        success_indices1 = (y_test < 0)
        success_rate1 = success_indices1[sale_indices].sum() / sale_indices.sum()
        print('    空头成功率 ：'+'{:.5f}'.format(success_rate1))

# %%
#根据投资策略设定参数（如预测涨幅大于0.2时可考虑买入，跌幅大于0.1时可考虑抛出）
buy_parameter = 0.2     
sale_parameter = -0.1

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    data2 = pd.read_csv(file_path)
    print('股票'+file_name[:-4])
    data3 = merge(individual(data2))
    train(data3,buy_parameter,sale_parameter)
# Out:
# 股票000001.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.62500
# 股票000002.SZ
#     没有购入条件
#     空头成功率 ：0.60870
# 股票000063.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.69231
# 股票000069.SZ
#     没有购入条件
#     空头成功率 ：1.00000
# 股票000100.SZ
#     没有购入条件
#     空头成功率 ：1.00000
# 股票000157.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.50000
# 股票000166.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.50000
# 股票000301.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.80000
# 股票000333.SZ
#     多头成功率 ：0.80000
#     空头成功率 ：0.64000
# 股票000338.SZ
#     多头成功率 ：0.80000
#     空头成功率 ：0.53846
# 股票000408.SZ
#     多头成功率 ：0.57143
#     空头成功率 ：0.43750
# 股票000425.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.44444
# 股票000538.SZ
#     多头成功率 ：0.62500
#     空头成功率 ：0.64286
# 股票000568.SZ
#     多头成功率 ：0.53333
#     空头成功率 ：0.70968
# 股票000596.SZ
#     多头成功率 ：0.68421
#     空头成功率 ：0.71429
# 股票000617.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.60000
# 股票000625.SZ
#     多头成功率 ：0.77778
#     空头成功率 ：0.60000
# 股票000651.SZ
#     多头成功率 ：0.33333
#     空头成功率 ：0.65385
# 股票000661.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.64000
# 股票000708.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.70588
# 股票000723.SZ
#     没有购入条件
#     空头成功率 ：0.75000
# 股票000725.SZ
#     没有购入条件
#     没有抛出条件
# 股票000733.SZ
#     多头成功率 ：0.56250
#     空头成功率 ：0.61290
# 股票000768.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.55000
# 股票000776.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.60000
# 股票000786.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.62963
# 股票000792.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.53846
# 股票000800.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.71429
# 股票000858.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.68966
# 股票000876.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.12500
# 股票000877.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.33333
# 股票000895.SZ
#     多头成功率 ：0.90909
#     空头成功率 ：0.83333
# 股票000938.SZ
#     多头成功率 ：0.69231
#     空头成功率 ：0.58621
# 股票000963.SZ
#     多头成功率 ：0.53846
#     空头成功率 ：0.68182
# 股票000977.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.59091
# 股票000983.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.83333
# 股票000999.SZ
#     多头成功率 ：0.41667
#     空头成功率 ：0.81250
# 股票001289.SZ
#     多头成功率 ：0.83333
#     空头成功率 ：0.47059
# 股票001979.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.68421
# 股票002001.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.75000
# 股票002007.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.76923
# 股票002008.SZ
#     多头成功率 ：0.77778
#     空头成功率 ：0.63636
# 股票002027.SZ
#     没有购入条件
#     空头成功率 ：1.00000
# 股票002032.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.60000
# 股票002049.SZ
#     多头成功率 ：0.77778
#     空头成功率 ：0.58621
# 股票002050.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.44444
# 股票002064.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：1.00000
# 股票002074.SZ
#     多头成功率 ：0.81818
#     空头成功率 ：0.73077
# 股票002120.SZ
#     没有购入条件
#     空头成功率 ：0.66667
# 股票002129.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.61538
# 股票002142.SZ
#     多头成功率 ：0.80000
#     空头成功率 ：0.73913
# 股票002179.SZ
#     多头成功率 ：0.73684
#     空头成功率 ：0.68421
# 股票002180.SZ
#     多头成功率 ：0.55556
#     空头成功率 ：0.54839
# 股票002202.SZ
#     没有购入条件
#     空头成功率 ：0.66667
# 股票002230.SZ
#     多头成功率 ：0.65385
#     空头成功率 ：0.47059
# 股票002236.SZ
#     多头成功率 ：0.64286
#     空头成功率 ：0.66667
# 股票002241.SZ
#     多头成功率 ：0.53333
#     空头成功率 ：0.46154
# 股票002252.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：1.00000
# 股票002271.SZ
#     多头成功率 ：0.87500
#     空头成功率 ：0.75862
# 股票002304.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.70000
# 股票002311.SZ
#     多头成功率 ：0.75000
#     空头成功率 ：0.72000
# 股票002352.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.75000
# 股票002371.SZ
#     多头成功率 ：0.78261
#     空头成功率 ：0.68000
# 股票002410.SZ
#     多头成功率 ：0.57143
#     空头成功率 ：0.60714
# 股票002414.SZ
#     没有购入条件
#     空头成功率 ：0.50000
# 股票002415.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.75862
# 股票002459.SZ
#     多头成功率 ：0.72727
#     空头成功率 ：0.63333
# 股票002460.SZ
#     多头成功率 ：0.61538
#     空头成功率 ：0.57143
# 股票002466.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.67857
# 股票002475.SZ
#     多头成功率 ：0.47368
#     空头成功率 ：0.53846
# 股票002493.SZ
#     多头成功率 ：0.00000
#     空头成功率 ：0.75000
# 股票002555.SZ
#     多头成功率 ：0.53333
#     空头成功率 ：0.64286
# 股票002594.SZ
#     多头成功率 ：0.75000
#     空头成功率 ：0.60714
# 股票002600.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.25000
# 股票002601.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.66667
# 股票002602.SZ
#     多头成功率 ：0.75000
#     空头成功率 ：0.71429
# 股票002603.SZ
#     多头成功率 ：0.69231
#     空头成功率 ：0.56250
# 股票002648.SZ
#     多头成功率 ：0.80000
#     空头成功率 ：0.85714
# 股票002709.SZ
#     多头成功率 ：0.64286
#     空头成功率 ：0.61290
# 股票002714.SZ
#     多头成功率 ：0.78947
#     空头成功率 ：0.40909
# 股票002736.SZ
#     多头成功率 ：1.00000
#     空头成功率 ：0.83333
# 股票002756.SZ
#     多头成功率 ：0.41667
#     空头成功率 ：0.53571
# 股票002812.SZ
#     多头成功率 ：0.58333
#     空头成功率 ：0.77143
# 股票002821.SZ
#     多头成功率 ：0.62500
#     空头成功率 ：0.62069
# 股票002841.SZ
#     多头成功率 ：0.57895
#     空头成功率 ：0.52174
# 股票002916.SZ
#     多头成功率 ：0.55000
#     空头成功率 ：0.68182
# 股票002920.SZ
#     多头成功率 ：0.70588
#     空头成功率 ：0.56000
# 股票002938.SZ
#     多头成功率 ：0.81818
#     空头成功率 ：0.50000
# 股票003816.SZ
#     没有购入条件
#     没有抛出条件
# 股票300014.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.62069
# 股票300015.SZ
#     多头成功率 ：0.27273
#     空头成功率 ：0.73913
# 股票300033.SZ
#     多头成功率 ：0.36842
#     空头成功率 ：0.48276
# 股票300059.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.61111
# 股票300122.SZ
#     多头成功率 ：0.57143
#     空头成功率 ：0.61905
# 股票300124.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.76190
# 股票300142.SZ
#     多头成功率 ：0.63636
#     空头成功率 ：0.62500
# 股票300207.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.62500
# 股票300223.SZ
#     多头成功率 ：0.59091
#     空头成功率 ：0.65217
# 股票300274.SZ
#     多头成功率 ：0.62500
#     空头成功率 ：0.46875
# 股票300308.SZ
#     多头成功率 ：0.54167
#     空头成功率 ：0.55556
# 股票300316.SZ
#     多头成功率 ：0.45000
#     空头成功率 ：0.70370
# 股票300347.SZ
#     多头成功率 ：0.46667
#     空头成功率 ：0.56667
# 股票300408.SZ
#     多头成功率 ：0.40000
#     空头成功率 ：0.64000
# 股票300413.SZ
#     多头成功率 ：0.71429
#     空头成功率 ：0.78261
# 股票300433.SZ
#     多头成功率 ：0.50000
#     空头成功率 ：0.60000
# 股票300450.SZ
#     多头成功率 ：0.54545
#     空头成功率 ：0.60000
# 股票300454.SZ
#     多头成功率 ：0.60000
#     空头成功率 ：0.71429
# 股票300496.SZ
#     多头成功率 ：0.56522
#     空头成功率 ：0.61905
# 股票300498.SZ
#     多头成功率 ：0.55556
#     空头成功率 ：0.50000
# 股票300529.SZ
#     多头成功率 ：0.62500
#     空头成功率 ：0.68750
# 股票300595.SZ
#     多头成功率 ：0.75000
#     空头成功率 ：0.58333
# 股票300601.SZ
#     多头成功率 ：0.53333
#     空头成功率 ：0.60000
# 股票300628.SZ
#     多头成功率 ：0.52941
#     空头成功率 ：0.60000
# 股票300661.SZ
#     多头成功率 ：0.61111
#     空头成功率 ：0.66667
# 股票300750.SZ
#     多头成功率 ：0.70833
#     空头成功率 ：0.78261
# 股票300751.SZ
#     多头成功率 ：0.73684
#     空头成功率 ：0.75862
# 股票300759.SZ
#     多头成功率 ：0.66667
#     空头成功率 ：0.66667
# 股票300760.SZ
#     多头成功率 ：0.75000
#     空头成功率 ：0.77273
# 股票300763.SZ
#     多头成功率 ：0.56250
#     空头成功率 ：0.65625
# 股票300769.SZ
#     多头成功率 ：0.62500
#     空头成功率 ：0.62500
# 股票300782.SZ
#     多头成功率 ：0.70588
#     空头成功率 ：0.69231
# 股票300896.SZ
#     多头成功率 ：0.57143
#     空头成功率 ：0.66667
# 股票300919.SZ
#     多头成功率 ：0.61538
#     空头成功率 ：0.73077
# 股票300957.SZ
#     多头成功率 ：0.55556
#     空头成功率 ：0.61111
# 股票300979.SZ
#     多头成功率 ：0.58333
#     空头成功率 ：0.62069
# 股票300999.SZ
#     多头成功率 ：0.60000
#     空头成功率 ：0.80952
# 股票301269.SZ
#     多头成功率 ：0.64000
#     空头成功率 ：0.70588
# 股票600000.SH
#     没有购入条件
#     没有抛出条件
# 股票600009.SH
#     多头成功率 ：0.71429
#     空头成功率 ：0.62069
# 股票600010.SH
#     没有购入条件
#     没有抛出条件
# 股票600011.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.75000
# 股票600015.SH
#     没有购入条件
#     没有抛出条件
# 股票600016.SH
#     没有购入条件
#     没有抛出条件
# 股票600018.SH
#     没有购入条件
#     空头成功率 ：1.00000
# 股票600019.SH
#     没有购入条件
#     空头成功率 ：0.33333
# 股票600023.SH
#     没有购入条件
#     空头成功率 ：0.00000
# 股票600025.SH
#     没有购入条件
#     空头成功率 ：0.66667
# 股票600028.SH
#     多头成功率 ：0.00000
#     空头成功率 ：0.50000
# 股票600029.SH
#     没有购入条件
#     空头成功率 ：0.62500
# 股票600030.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.47059
# 股票600031.SH
#     多头成功率 ：0.83333
#     空头成功率 ：0.75000
# 股票600036.SH
#     多头成功率 ：0.77778
#     空头成功率 ：0.68000
# 股票600039.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.80000
# 股票600048.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.61905
# 股票600050.SH
#     多头成功率 ：0.71429
#     空头成功率 ：1.00000
# 股票600061.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.80000
# 股票600085.SH
#     多头成功率 ：0.65000
#     空头成功率 ：0.64706
# 股票600089.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.56250
# 股票600104.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.70000
# 股票600111.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.60000
# 股票600115.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.66667
# 股票600132.SH
#     多头成功率 ：0.61111
#     空头成功率 ：0.66667
# 股票600150.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.40000
# 股票600176.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.84615
# 股票600183.SH
#     多头成功率 ：0.53846
#     空头成功率 ：0.53846
# 股票600188.SH
#     多头成功率 ：0.53846
#     空头成功率 ：0.53571
# 股票600196.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.78947
# 股票600219.SH
#     没有购入条件
#     没有抛出条件
# 股票600233.SH
#     多头成功率 ：0.25000
#     空头成功率 ：0.83333
# 股票600276.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.55172
# 股票600309.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.82609
# 股票600332.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.88889
# 股票600346.SH
#     多头成功率 ：0.88889
#     空头成功率 ：0.45455
# 股票600362.SH
#     多头成功率 ：0.80000
#     空头成功率 ：0.75000
# 股票600372.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.36364
# 股票600383.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.64286
# 股票600406.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.61111
# 股票600426.SH
#     多头成功率 ：0.68750
#     空头成功率 ：0.55000
# 股票600436.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.71429
# 股票600438.SH
#     多头成功率 ：0.45455
#     空头成功率 ：0.75000
# 股票600460.SH
#     多头成功率 ：0.37500
#     空头成功率 ：0.66667
# 股票600489.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.62500
# 股票600515.SH
#     多头成功率 ：0.00000
#     没有抛出条件
# 股票600519.SH
#     多头成功率 ：0.57143
#     空头成功率 ：0.66667
# 股票600547.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.66667
# 股票600570.SH
#     多头成功率 ：0.44444
#     空头成功率 ：0.66667
# 股票600584.SH
#     多头成功率 ：0.93333
#     空头成功率 ：0.55556
# 股票600585.SH
#     多头成功率 ：0.33333
#     空头成功率 ：0.50000
# 股票600588.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.66667
# 股票600600.SH
#     多头成功率 ：0.64706
#     空头成功率 ：0.84615
# 股票600606.SH
#     没有购入条件
#     没有抛出条件
# 股票600660.SH
#     多头成功率 ：0.87500
#     空头成功率 ：0.83333
# 股票600674.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.33333
# 股票600690.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.78947
# 股票600732.SH
#     多头成功率 ：0.70000
#     空头成功率 ：0.56667
# 股票600741.SH
#     多头成功率 ：0.71429
#     空头成功率 ：0.60000
# 股票600745.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.62500
# 股票600754.SH
#     多头成功率 ：0.42857
#     空头成功率 ：0.66667
# 股票600760.SH
#     多头成功率 ：0.57895
#     空头成功率 ：0.52941
# 股票600763.SH
#     多头成功率 ：0.70588
#     空头成功率 ：0.62069
# 股票600795.SH
#     没有购入条件
#     没有抛出条件
# 股票600803.SH
#     多头成功率 ：0.83333
#     空头成功率 ：0.44444
# 股票600809.SH
#     多头成功率 ：0.52174
#     空头成功率 ：0.75000
# 股票600837.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.50000
# 股票600845.SH
#     多头成功率 ：0.70000
#     空头成功率 ：0.65000
# 股票600875.SH
#     多头成功率 ：0.83333
#     空头成功率 ：0.60000
# 股票600884.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.68750
# 股票600886.SH
#     没有购入条件
#     空头成功率 ：0.50000
# 股票600887.SH
#     多头成功率 ：0.77778
#     空头成功率 ：0.57143
# 股票600893.SH
#     多头成功率 ：0.76923
#     空头成功率 ：0.62500
# 股票600900.SH
#     多头成功率 ：0.83333
#     空头成功率 ：0.00000
# 股票600905.SH
#     没有购入条件
#     没有抛出条件
# 股票600918.SH
#     没有购入条件
#     空头成功率 ：0.00000
# 股票600919.SH
#     没有购入条件
#     空头成功率 ：0.50000
# 股票600926.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.92308
# 股票600938.SH
#     多头成功率 ：0.55556
#     空头成功率 ：0.85714
# 股票600941.SH
#     多头成功率 ：0.69231
#     空头成功率 ：0.61905
# 股票600958.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.54545
# 股票600989.SH
#     多头成功率 ：0.80000
#     空头成功率 ：0.53846
# 股票600999.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.75000
# 股票601006.SH
#     没有购入条件
#     空头成功率 ：1.00000
# 股票601009.SH
#     没有购入条件
#     空头成功率 ：0.57143
# 股票601012.SH
#     多头成功率 ：0.53846
#     空头成功率 ：0.65385
# 股票601021.SH
#     多头成功率 ：0.58824
#     空头成功率 ：0.60714
# 股票601059.SH
#     多头成功率 ：0.83333
#     空头成功率 ：0.71429
# 股票601066.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.80000
# 股票601088.SH
#     多头成功率 ：0.62500
#     空头成功率 ：0.50000
# 股票601100.SH
#     多头成功率 ：0.80000
#     空头成功率 ：0.45833
# 股票601111.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.70000
# 股票601117.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.87500
# 股票601138.SH
#     多头成功率 ：0.42857
#     空头成功率 ：0.66667
# 股票601155.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.68000
# 股票601166.SH
#     没有购入条件
#     空头成功率 ：0.88889
# 股票601169.SH
#     没有购入条件
#     没有抛出条件
# 股票601186.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.50000
# 股票601211.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.50000
# 股票601216.SH
#     没有购入条件
#     空头成功率 ：1.00000
# 股票601225.SH
#     多头成功率 ：0.80000
#     空头成功率 ：0.64706
# 股票601229.SH
#     没有购入条件
#     没有抛出条件
# 股票601236.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.40000
# 股票601238.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.85714
# 股票601288.SH
#     没有购入条件
#     没有抛出条件
# 股票601318.SH
#     多头成功率 ：0.70000
#     空头成功率 ：0.70968
# 股票601319.SH
#     多头成功率 ：0.00000
#     空头成功率 ：1.00000
# 股票601328.SH
#     没有购入条件
#     空头成功率 ：1.00000
# 股票601336.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.58333
# 股票601360.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.55556
# 股票601377.SH
#     没有购入条件
#     空头成功率 ：0.50000
# 股票601390.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.40000
# 股票601398.SH
#     没有购入条件
#     空头成功率 ：0.50000
# 股票601600.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.71429
# 股票601601.SH
#     多头成功率 ：0.55556
#     空头成功率 ：0.50000
# 股票601607.SH
#     多头成功率 ：0.42857
#     空头成功率 ：0.61538
# 股票601615.SH
#     多头成功率 ：0.42857
#     空头成功率 ：0.72222
# 股票601618.SH
#     没有购入条件
#     没有抛出条件
# 股票601628.SH
#     多头成功率 ：0.33333
#     空头成功率 ：0.45000
# 股票601633.SH
#     多头成功率 ：0.77778
#     空头成功率 ：0.52174
# 股票601658.SH
#     没有购入条件
#     空头成功率 ：0.80000
# 股票601668.SH
#     没有购入条件
#     空头成功率 ：0.66667
# 股票601669.SH
#     没有购入条件
#     空头成功率 ：0.75000
# 股票601688.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.71429
# 股票601689.SH
#     多头成功率 ：0.57143
#     空头成功率 ：0.44828
# 股票601698.SH
#     多头成功率 ：0.61538
#     空头成功率 ：0.35294
# 股票601699.SH
#     多头成功率 ：0.80000
#     空头成功率 ：0.55000
# 股票601728.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.60000
# 股票601766.SH
#     没有购入条件
#     空头成功率 ：0.50000
# 股票601788.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.33333
# 股票601799.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.59259
# 股票601800.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.50000
# 股票601808.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.70000
# 股票601816.SH
#     没有购入条件
#     空头成功率 ：1.00000
# 股票601818.SH
#     没有购入条件
#     没有抛出条件
# 股票601838.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.82353
# 股票601857.SH
#     多头成功率 ：0.33333
#     空头成功率 ：1.00000
# 股票601865.SH
#     多头成功率 ：0.87500
#     空头成功率 ：0.59375
# 股票601868.SH
#     没有购入条件
#     没有抛出条件
# 股票601872.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.60000
# 股票601877.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.59259
# 股票601878.SH
#     没有购入条件
#     空头成功率 ：0.44444
# 股票601881.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.50000
# 股票601888.SH
#     多头成功率 ：0.46154
#     空头成功率 ：0.61765
# 股票601898.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.60000
# 股票601899.SH
#     多头成功率 ：0.71429
#     空头成功率 ：0.62500
# 股票601901.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.50000
# 股票601916.SH
#     没有购入条件
#     没有抛出条件
# 股票601919.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.62500
# 股票601939.SH
#     没有购入条件
#     空头成功率 ：1.00000
# 股票601966.SH
#     多头成功率 ：0.62500
#     空头成功率 ：0.60000
# 股票601985.SH
#     没有购入条件
#     没有抛出条件
# 股票601988.SH
#     没有购入条件
#     空头成功率 ：0.00000
# 股票601989.SH
#     多头成功率 ：1.00000
#     没有抛出条件
# 股票601995.SH
#     多头成功率 ：0.88889
#     空头成功率 ：0.54167
# 股票601998.SH
#     多头成功率 ：0.50000
#     空头成功率 ：0.00000
# 股票603019.SH
#     多头成功率 ：0.47368
#     空头成功率 ：0.42857
# 股票603185.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.67857
# 股票603195.SH
#     多头成功率 ：0.61905
#     空头成功率 ：0.60870
# 股票603259.SH
#     多头成功率 ：0.71429
#     空头成功率 ：0.68421
# 股票603260.SH
#     多头成功率 ：0.76923
#     空头成功率 ：0.58621
# 股票603288.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.75000
# 股票603290.SH
#     多头成功率 ：0.61538
#     空头成功率 ：0.57143
# 股票603369.SH
#     多头成功率 ：0.47619
#     空头成功率 ：0.77778
# 股票603392.SH
#     多头成功率 ：0.53846
#     空头成功率 ：0.53571
# 股票603486.SH
#     多头成功率 ：0.40000
#     空头成功率 ：0.63333
# 股票603501.SH
#     多头成功率 ：0.47619
#     空头成功率 ：0.62500
# 股票603659.SH
#     多头成功率 ：0.54545
#     空头成功率 ：0.78571
# 股票603799.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.65625
# 股票603806.SH
#     多头成功率 ：0.57143
#     空头成功率 ：0.75862
# 股票603833.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.66667
# 股票603882.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.68966
# 股票603899.SH
#     多头成功率 ：0.54545
#     空头成功率 ：0.70833
# 股票603986.SH
#     多头成功率 ：0.57143
#     空头成功率 ：0.68182
# 股票603993.SH
#     多头成功率 ：1.00000
#     空头成功率 ：1.00000
# 股票605117.SH
#     多头成功率 ：0.88889
#     空头成功率 ：0.66667
# 股票605499.SH
#     多头成功率 ：0.70000
#     空头成功率 ：0.60000
# 股票688005.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.56250
# 股票688008.SH
#     多头成功率 ：0.65000
#     空头成功率 ：0.56522
# 股票688012.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.54545
# 股票688036.SH
#     多头成功率 ：0.62963
#     空头成功率 ：0.66667
# 股票688041.SH
#     多头成功率 ：0.61111
#     空头成功率 ：0.42308
# 股票688065.SH
#     多头成功率 ：0.58333
#     空头成功率 ：0.41379
# 股票688111.SH
#     多头成功率 ：0.52174
#     空头成功率 ：0.78261
# 股票688126.SH
#     多头成功率 ：0.57143
#     空头成功率 ：0.60000
# 股票688169.SH
#     多头成功率 ：0.61538
#     空头成功率 ：0.68182
# 股票688187.SH
#     多头成功率 ：0.66667
#     空头成功率 ：0.73077
# 股票688223.SH
#     多头成功率 ：1.00000
#     空头成功率 ：0.62500
# 股票688256.SH
#     多头成功率 ：0.62069
#     空头成功率 ：0.55000
# 股票688271.SH
#     多头成功率 ：0.61538
#     空头成功率 ：0.77273
# 股票688303.SH
#     多头成功率 ：0.80000
#     空头成功率 ：0.70833
# 股票688363.SH
#     多头成功率 ：0.54545
#     空头成功率 ：0.75000
# 股票688396.SH
#     多头成功率 ：0.71429
#     空头成功率 ：0.69565
# 股票688561.SH
#     多头成功率 ：0.60000
#     空头成功率 ：0.54545
# 股票688599.SH
#     多头成功率 ：0.70000
#     空头成功率 ：0.54839
# 股票688981.SH
#     多头成功率 ：0.75000
#     空头成功率 ：0.47619
